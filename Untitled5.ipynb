# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_excel(r'./prac data/employee.xlsx')
df
# Out:
#     emp_id   first_name   last_name  hire_date
# 0      100       Steven        King 2003-06-17
# 1      101        Neena     Kochhar 2005-09-21
# 2      102          Lex     De Haan 2001-01-13
# 3      103    Alexander      Hunold 2006-01-03
# 4      104        Bruce       Ernst 2007-05-21
# 5      105        David      Austin 2005-06-25
# 6      106        Valli   Pataballa 2006-02-05
# 7      107        Diana     Lorentz 2007-02-07
# 8      108        Nancy   Greenberg 2002-08-17
# 9      109       Daniel      Faviet 2002-08-16
# 10     110         John        Chen 2005-09-28
# 11     111       Ismael     Sciarra 2005-09-30
# 12     112  Jose Manuel       Urman 2006-03-07
# 13     113         Luis        Popp 2007-12-07
# 14     114          Den    Raphaely 2002-12-07
# 15     115    Alexander        Khoo 2003-05-18
# 16     116       Shelli       Baida 2005-12-24
# 17     117        Sigal      Tobias 2005-07-24
# 18     118          Guy      Himuro 2006-11-15
# ...

# %%
#sorting the dataframe
df.head()
# Out:
#    emp_id first_name last_name  hire_date
# 0     100     Steven      King 2003-06-17
# 1     101      Neena   Kochhar 2005-09-21
# 2     102        Lex   De Haan 2001-01-13
# 3     103  Alexander    Hunold 2006-01-03
# 4     104      Bruce     Ernst 2007-05-21

# %%
df.sort_values(by ='last_name')
# Out:
#     emp_id   first_name   last_name  hire_date
# 5      105        David      Austin 2005-06-25
# 16     116       Shelli       Baida 2005-12-24
# 10     110         John        Chen 2005-09-28
# 19     119        Karen  Colmenares 2007-08-10
# 2      102          Lex     De Haan 2001-01-13
# 4      104        Bruce       Ernst 2007-05-21
# 9      109       Daniel      Faviet 2002-08-16
# 8      108        Nancy   Greenberg 2002-08-17
# 18     118          Guy      Himuro 2006-11-15
# 3      103    Alexander      Hunold 2006-01-03
# 15     115    Alexander        Khoo 2003-05-18
# 0      100       Steven        King 2003-06-17
# 1      101        Neena     Kochhar 2005-09-21
# 7      107        Diana     Lorentz 2007-02-07
# 6      106        Valli   Pataballa 2006-02-05
# 13     113         Luis        Popp 2007-12-07
# 14     114          Den    Raphaely 2002-12-07
# 11     111       Ismael     Sciarra 2005-09-30
# 17     117        Sigal      Tobias 2005-07-24
# ...

# %%
df.sort_values(by='last_name', ignore_index = True)
# Out:
#     emp_id   first_name   last_name  hire_date
# 0      105        David      Austin 2005-06-25
# 1      116       Shelli       Baida 2005-12-24
# 2      110         John        Chen 2005-09-28
# 3      119        Karen  Colmenares 2007-08-10
# 4      102          Lex     De Haan 2001-01-13
# 5      104        Bruce       Ernst 2007-05-21
# 6      109       Daniel      Faviet 2002-08-16
# 7      108        Nancy   Greenberg 2002-08-17
# 8      118          Guy      Himuro 2006-11-15
# 9      103    Alexander      Hunold 2006-01-03
# 10     115    Alexander        Khoo 2003-05-18
# 11     100       Steven        King 2003-06-17
# 12     101        Neena     Kochhar 2005-09-21
# 13     107        Diana     Lorentz 2007-02-07
# 14     106        Valli   Pataballa 2006-02-05
# 15     113         Luis        Popp 2007-12-07
# 16     114          Den    Raphaely 2002-12-07
# 17     111       Ismael     Sciarra 2005-09-30
# 18     117        Sigal      Tobias 2005-07-24
# ...

# %%
#sorting on multiple columns
df.sort_values(by = ['hire_date','first_name'], ignore_index= True)
# Out:
#     emp_id   first_name   last_name  hire_date
# 0      102          Lex     De Haan 2001-01-13
# 1      109       Daniel      Faviet 2002-08-16
# 2      108        Nancy   Greenberg 2002-08-17
# 3      114          Den    Raphaely 2002-12-07
# 4      115    Alexander        Khoo 2003-05-18
# 5      100       Steven        King 2003-06-17
# 6      105        David      Austin 2005-06-25
# 7      117        Sigal      Tobias 2005-07-24
# 8      101        Neena     Kochhar 2005-09-21
# 9      110         John        Chen 2005-09-28
# 10     111       Ismael     Sciarra 2005-09-30
# 11     116       Shelli       Baida 2005-12-24
# 12     103    Alexander      Hunold 2006-01-03
# 13     106        Valli   Pataballa 2006-02-05
# 14     112  Jose Manuel       Urman 2006-03-07
# 15     118          Guy      Himuro 2006-11-15
# 16     107        Diana     Lorentz 2007-02-07
# 17     104        Bruce       Ernst 2007-05-21
# 18     119        Karen  Colmenares 2007-08-10
# ...

# %%
df.sort_values(by='last_name', ignore_index=True, ascending=False)
# Out:
#     emp_id   first_name   last_name  hire_date
# 0      112  Jose Manuel       Urman 2006-03-07
# 1      117        Sigal      Tobias 2005-07-24
# 2      111       Ismael     Sciarra 2005-09-30
# 3      114          Den    Raphaely 2002-12-07
# 4      113         Luis        Popp 2007-12-07
# 5      106        Valli   Pataballa 2006-02-05
# 6      107        Diana     Lorentz 2007-02-07
# 7      101        Neena     Kochhar 2005-09-21
# 8      100       Steven        King 2003-06-17
# 9      115    Alexander        Khoo 2003-05-18
# 10     103    Alexander      Hunold 2006-01-03
# 11     118          Guy      Himuro 2006-11-15
# 12     108        Nancy   Greenberg 2002-08-17
# 13     109       Daniel      Faviet 2002-08-16
# 14     104        Bruce       Ernst 2007-05-21
# 15     102          Lex     De Haan 2001-01-13
# 16     119        Karen  Colmenares 2007-08-10
# 17     110         John        Chen 2005-09-28
# 18     116       Shelli       Baida 2005-12-24
# ...

# %%
#splitting the dataframe into numerical
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   emp_id      20 non-null     int64
#  1   first_name  20 non-null     object
#  2   last_name   20 non-null     object
#  3   hire_date   20 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 772.0+ bytes

# %%
num_data=df.select_dtypes('number')

# %%
num_data
# Out:
#     emp_id
# 0      100
# 1      101
# 2      102
# 3      103
# 4      104
# 5      105
# 6      106
# 7      107
# 8      108
# 9      109
# 10     110
# 11     111
# 12     112
# 13     113
# 14     114
# 15     115
# 16     116
# 17     117
# 18     118
# 19     119

# %%
num_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   emp_id  20 non-null     int64
# dtypes: int64(1)
# memory usage: 292.0 bytes

# %%
obj_data=df.select_dtypes('object')
obj_data
# Out:
#      first_name   last_name
# 0        Steven        King
# 1         Neena     Kochhar
# 2           Lex     De Haan
# 3     Alexander      Hunold
# 4         Bruce       Ernst
# 5         David      Austin
# 6         Valli   Pataballa
# 7         Diana     Lorentz
# 8         Nancy   Greenberg
# 9        Daniel      Faviet
# 10         John        Chen
# 11       Ismael     Sciarra
# 12  Jose Manuel       Urman
# 13         Luis        Popp
# 14          Den    Raphaely
# 15    Alexander        Khoo
# 16       Shelli       Baida
# 17        Sigal      Tobias
# 18          Guy      Himuro
# 19        Karen  Colmenares

# %%
obj_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first_name  20 non-null     object
#  1   last_name   20 non-null     object
# dtypes: object(2)
# memory usage: 452.0+ bytes

# %%
#iterating 
for i in df:
    print(i)
# Out:
# emp_id
# first_name
# last_name
# hire_date

# %%
for i in df:
    print(i)
    print('*********')
    print(df[i])
    print(df[i+1])
# Out:
# emp_id
# *********
# 0     100
# 1     101
# 2     102
# 3     103
# 4     104
# 5     105
# 6     106
# 7     107
# 8     108
# 9     109
# 10    110
# 11    111
# 12    112
# 13    113
# 14    114
# 15    115
# 16    116
# 17    117
# 18    118
# 19    119
# Name: emp_id, dtype: int64
# first_name
# *********
# 0          Steven
# 1           Neena
# 2             Lex
# 3       Alexander
# 4           Bruce
# 5           David
# 6           Valli
# 7           Diana
# 8           Nancy
# 9          Daniel
# 10           John
# 11         Ismael
# 12    Jose Manuel
# 13           Luis
# 14            Den
# 15      Alexander
# 16         Shelli
# 17          Sigal
# 18            Guy
# 19          Karen
# Name: first_name, dtype: object
# last_name
# *********
# 0           King
# 1        Kochhar
# 2        De Haan
# 3         Hunold
# 4          Ernst
# 5         Austin
# 6      Pataballa
# 7        Lorentz
# 8      Greenberg
# 9         Faviet
# 10          Chen
# ...

# %%
for i in df.item():
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 for i in df.last_name():
#       2     print(i)
#
# TypeError: 'Series' object is not callable

# %%
#iterrows()
#it also generates a generator object
#each elemnet inside the genrator object is a tuple
for i in df.iterrows():
    print(i)
# Out:
# (0, emp_id                        100
# first_name                 Steven
# last_name                    King
# hire_date     2003-06-17 00:00:00
# Name: 0, dtype: object)
# (1, emp_id                        101
# first_name                  Neena
# last_name                 Kochhar
# hire_date     2005-09-21 00:00:00
# Name: 1, dtype: object)
# (2, emp_id                        102
# first_name                    Lex
# last_name                 De Haan
# hire_date     2001-01-13 00:00:00
# Name: 2, dtype: object)
# (3, emp_id                        103
# first_name              Alexander
# last_name                  Hunold
# hire_date     2006-01-03 00:00:00
# Name: 3, dtype: object)
# (4, emp_id                        104
# first_name                  Bruce
# last_name                   Ernst
# hire_date     2007-05-21 00:00:00
# Name: 4, dtype: object)
# (5, emp_id                        105
# first_name                  David
# last_name                  Austin
# ...

# %%
df.itertuples()

# %%
for i in df.itertuples():
    print (i)
# Out:
# Pandas(Index=0, emp_id=100, first_name='Steven', last_name='King', hire_date=Timestamp('2003-06-17 00:00:00'))
# Pandas(Index=1, emp_id=101, first_name='Neena', last_name='Kochhar', hire_date=Timestamp('2005-09-21 00:00:00'))
# Pandas(Index=2, emp_id=102, first_name='Lex', last_name='De Haan', hire_date=Timestamp('2001-01-13 00:00:00'))
# Pandas(Index=3, emp_id=103, first_name='Alexander', last_name='Hunold', hire_date=Timestamp('2006-01-03 00:00:00'))
# Pandas(Index=4, emp_id=104, first_name='Bruce', last_name='Ernst', hire_date=Timestamp('2007-05-21 00:00:00'))
# Pandas(Index=5, emp_id=105, first_name='David', last_name='Austin', hire_date=Timestamp('2005-06-25 00:00:00'))
# Pandas(Index=6, emp_id=106, first_name='Valli', last_name='Pataballa', hire_date=Timestamp('2006-02-05 00:00:00'))
# Pandas(Index=7, emp_id=107, first_name='Diana', last_name='Lorentz', hire_date=Timestamp('2007-02-07 00:00:00'))
# ...

# %%
#how to export data frame
emp={'name':['Mayank','Rishabh','Geetikaa' , 'Deepika'], 'ID' : [101,102,103,104], 'city':['surat','pune','ahmedabad','vapi']}

# %% [markdown]
# emp

# %%
emp
# Out:
# {'name': ['Mayank', 'Rishabh', 'Geetikaa', 'Deepika'],
#  'ID': [101, 102, 103, 104],
#  'city': ['surat', 'pune', 'ahmedabad', 'vapi']}

# %%
df=pd.DataFrame(emp)

# %%
df
# Out:
#        name   ID       city
# 0    Mayank  101      surat
# 1   Rishabh  102       pune
# 2  Geetikaa  103  ahmedabad
# 3   Deepika  104       vapi

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd
df=pd.read_csv('titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Age'].isnull().sum()
# Out:
# 177

# %%
df.Age.fillna(df.Age.median(), inplace= True)

# %%
df['Age'].isna().sum()
# Out:
# 0

# %%
plt.boxplot(df.Age)
plt.show()

# %%
import seaborn as sns

# %%
sns.histplot(x='Age',data=df,bins=10)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
#barplot
# it is used to plot one categorical column and one discrete column
name=['Gagan','Sourav','Pooja','Shweta']
salary=[10000,20000,30000,40000]
plt.barh(name,salary)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
plt.bar(df.Survived,df.Sex)
# Out:
# <BarContainer object of 891 artists>

# %%
plt.scatter(df['Fare'],df['Age'],color='r',marker='*')
plt.title('Fare')
# Out:
# Text(0.5, 1.0, 'Fare')

# %%
f,a = plt.subplots(2,2 ,figsize=(10,10),dpi=100)
a[0,0].pie(df.Sex.value_counts(), labels=df.Sex.value_counts().index,autopct='%.2f%%')
a[0,1].boxplot(df.Age)
a[1,0].bar(name,salary)
a[1,1].hist(df.Age)
plt.show()

# %%
import seaborn as sns

# %%
sns.barplot(df)
# Out:
# <Axes: >

# %%
sns.__version__
# Out:
# '0.12.2'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#it is used to plot a matplotlib plot on the searraborn dedfault.

sns.set()

# %%
sns.set_style('whitegrid', {'figure.facecolor':'white'})
plt.plot(arr,arr1)
plt.show()

# %%
a=[1,2,3,4,5,6]
b=['a','b','c','d','e','f']
arr=pd.array(a)

# %%
arr1=pd.array(b)

# %%
sns.set_context('talk')
plt.plot(arr,arr1)
plt.show()

# %%
sns.set_theme(style='darkgrid', context='paper',palette='bright',font_scale=1)

# %%
plt.plot(arr,arr1, color='r', ls='--',lw=3,marker='o',label='X vs Y', markerfacecolor='y', markeredgewidth=2, markersize=15,markeredgecolor='r')
plt.title('plot 1',fontdict={'font':'monospace'})
plt.show()

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
# ...

# %%
sns.load_dataset('glue')
# Out:
#           Model  Year      Encoder  Task  Score
# 0         ERNIE  2019  Transformer  CoLA   75.5
# 1            T5  2019  Transformer  CoLA   71.6
# 2       RoBERTa  2019  Transformer  CoLA   67.8
# 3          BERT  2018  Transformer  CoLA   60.5
# 4   BiLSTM+ELMo  2018         LSTM  CoLA   32.1
# ..          ...   ...          ...   ...    ...
# 59         BERT  2018  Transformer   RTE   70.1
# 60  BiLSTM+ELMo  2018         LSTM   RTE   57.4
# 61  BiLSTM+CoVe  2017         LSTM   RTE   52.7
# 62  BiLSTM+Attn  2017         LSTM   RTE   58.4
# 63       BiLSTM  2017         LSTM   RTE   57.4
#
# [64 rows x 5 columns]

# %%
sns.histplot(data=df)
# Out:
# <Axes: ylabel='Count'>

# %%
import pandas as pd
df=pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
import seaborn as sns
sns.boxplot(y='Age', data=df)
# Out:
# <Axes: ylabel='Age'>

# %%
import matplotlib.pyplot as plt

# %%
var=[1,23,4,5,6,77,7,8,9,]
var_1=[1,2,3,4,5,0,6,4,6]
plt.plot(var,var_1)
plt.show()

# %%
dt=pd.DataFrame({'var':var,'var_1':var_1})
sns.lineplot(x=var,y=var_1)
plt.show()

# %%
dataone=sns.load_dataset('penguins')

# %%
sns.lineplot(x='bill_length_mm',y='bill_depth_mm',data=dataone)
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>
