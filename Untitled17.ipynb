# %%
import matplotlib.pyplot as plt
x1=[1,2,3,4,5,6]
y=[230,320,234,534,330,300]
plt.plot(x1,y,marker='o',ls='dotted')

plt.xlabel("Dates")
plt.ylabel("Sales")
plt.title("Day wise sales")


plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 9
#       7 plt.ylabel("Sales")
#       8 plt.title("Day wise sales")
# ----> 9 plt.plot(days,max_t,label='Days')
#      10 plt.plot(days,min_t,label='MIN')
#      11 plt.plot(days,avt_t,label='AVG')
#
# NameError: name 'days' is not defined

# %%
fig, ax = plt.subplots()
fruits=['apple','blueberry','cherry','orange']
counts=[40,100,30,55]
bar_labels=['red','blue','_red','orange']
bar_colors=['tab:red','tab:blue','tab:red','tab:orange']
ax.bar(fruits,counts,label=bar_labels, color=bar_colors)
ax.set_ylabel('fruit supply')
ax.set_title('fruit supply by kind and color')
ax.legend(title='Fruit color')
plt.show()

# %%
days=[1,2,3,4,5,6]
max_t=[10,20,30,40,50,60]
min_t=[4,6,7,8,9,9]
avg_t=[6,15,25,30,40,50]
plt.plot(days,max_t,label='MAX')
plt.plot(days,min_t,label='MIN')
plt.plot(days,avg_t,label='AVG')
plt.legend(loc=8)

# %%
stock=[234,343,544]
company=['fb','google','msft']
plt.barh(company,stock)
# Out:
# <BarContainer object of 3 artists>

# %%
#histogrm
blood_sugar=[34,45,20,32,65,80,100]
p_name=('a','b','c','d','e','f','g')
plt.hist(blood_sugar,[20,40,50,100])
# Out:
# (array([3., 1., 3.]),
#  array([ 20.,  40.,  50., 100.]),
#  <BarContainer object of 3 artists>)

# %%
import pandas as pd
import seaborn as sns
df=sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df['age'].isnull().sum()
# Out:
# 177

# %%
x=df['age'].max()
y=df['age'].min()
x,y
# Out:
# (80.0, 0.42)

# %%
#yount- 0.42 -18
#adult - 18-55
#old-55-88
age1=df['age']
plt.hist(age1,[0,18,55,88])
plt.show()

# %%
plt.hist(df[df['survived']==0]['age'],bins=[0,18,55,88])
plt.show()

# %%
plt.hist(df[df['sex']=='male']['age'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
